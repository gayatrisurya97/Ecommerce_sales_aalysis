# %%
# Step 1: Install libraries if not already
# !pip install pandas sqlalchemy psycopg2-binary

# Step 2: Import libraries
import pandas as pd
from sqlalchemy import create_engine

# Step 3: Database credentials
host = "localhost"         # usually localhost if DB is on your machine
port = 5433                # default PostgreSQL port
database = "superstore"    # your DB name
username = "postgres"      # your DB username
password = "#gayuSurya9"   # your DB password

# Step 4: Create SQLAlchemy engine
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")


# Step 6: Load your table into pandas
df = pd.read_sql("SELECT * FROM orders", engine)  # replace 'orders' with your table name

# Step 7: Check data
print(df.head())
print(df.info())

# Step 8: Run analysis like before
total_orders = len(df)
total_sales = df['sales'].sum()
total_quantity = df['quantity'].sum()
total_profit = df['profit'].sum()
avg_discount = df['discount'].mean()

print(f"Total orders: {total_orders}")
print(f"Total sales: {total_sales}")
print(f"Total quantity: {total_quantity}")
print(f"Total profit: {total_profit}")
print(f"Average discount: {avg_discount:.2f}")
# Out:
#         ship_mode    segment        country             city       state  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   postal_code region         category sub_category   sales  quantity  \
# 0       42420  South        Furniture    Bookcases  261.96         2
# 1       42420  South        Furniture       Chairs  731.94         3
# 2       90036   West  Office Supplies       Labels   14.62         2
# 3       33311  South        Furniture       Tables  957.58         5
# 4       33311  South  Office Supplies      Storage   22.37         2
#
#    discount  profit
# 0      0.00   41.91
# 1      0.00  219.58
# 2      0.00    6.87
# 3      0.45 -383.03
# ...

# %%
engine = create_engine(f"postgresql+psycopg2://postgres:#gayuSurya9@localhost:5433/superstore")
df = pd.read_sql("SELECT * FROM orders", engine)
df
# Out:
#            ship_mode    segment        country             city       state  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Remove duplicates
df = df.drop_duplicates()

# Strip whitespace from text columns
text_cols = ["ship_mode", "segment", "country", "city",
             "state", "region", "category", "sub_category"]

for col in text_cols:
    df[col] = df[col].str.strip()
# Remove negative quantity (if any)
df = df[df["quantity"] > 0]
# Convert numeric columns properly
df["sales"] = pd.to_numeric(df["sales"], errors="coerce")
df["quantity"] = pd.to_numeric(df["quantity"], errors="coerce")
df["discount"] = pd.to_numeric(df["discount"], errors="coerce")
df["profit"] = pd.to_numeric(df["profit"], errors="coerce")

# Handle missing values
df = df.dropna()

# %%
df.to_sql(
    "clean_delays",
    engine,
    if_exists="replace",   # use 'append' in production
    index=False
)

print("Cleaned data saved successfully!")
# Out:
# Cleaned data saved successfully!
